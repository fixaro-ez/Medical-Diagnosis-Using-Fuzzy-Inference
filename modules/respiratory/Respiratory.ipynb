# %%
import pandas as pd
import json

# Load the dataset
df = pd.read_csv('respiratory symptoms and treatment.csv')

# Clean column names
df.columns = [c.strip() for c in df.columns]

# Clean string values
for col in ['Symptoms', 'Sex', 'Disease', 'Treatment', 'Nature']:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip()

# Convert Age to numeric, coercing errors to NaN
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# Initialize knowledge base
knowledge_base = {
    "symptoms_list": sorted(df['Symptoms'].unique().tolist()),
    "diseases": {}
}

# Group by Disease to extract rules
diseases = df['Disease'].unique()

for disease in diseases:
    subset = df[df['Disease'] == disease]
    total_cases = len(subset)
    
    # 1. Calculate Symptom Weights (Frequency / Total Cases)
    symptom_counts = subset['Symptoms'].value_counts()
    symptom_weights = (symptom_counts / total_cases).to_dict()
    
    # 2. Calculate Age Stats for Fuzzy Membership
    valid_ages = subset['Age'].dropna()
    if not valid_ages.empty:
        age_stats = {
            "min": float(valid_ages.min()),
            "max": float(valid_ages.max()),
            "mean": float(valid_ages.mean()),
            "std": float(valid_ages.std()) if len(valid_ages) > 1 else 5.0
        }
    else:
        age_stats = {"min": 0, "max": 100, "mean": 40, "std": 20}

    # 3. Get most common treatment
    try:
        treatment = subset['Treatment'].mode()[0]
    except:
        treatment = "Consult a Doctor"

    knowledge_base["diseases"][disease] = {
        "weights": symptom_weights,
        "age_profile": age_stats,
        "treatment": treatment
    }

# Output valid JSON
print(json.dumps(knowledge_base, indent=2))
# Out:
# {
#   "symptoms_list": [
#     "A cough that lasts more than three weeks",
#     "A dry, crackling sound in the lungs while breathing in",
#     "Bluish skin",
#     "Chest congestion",
#     "Chest pain",
#     "Chest tightness or chest pain",
#     "Chills",
#     "Coughing up blood",
#     "Coughing up yellow or green mucus daily",
#     "Daytime sleepiness",
#     "Difficulties with memory and concentration",
#     "Dry mouth",
#     "Fatigue",
#     "Fatigue, feeling run-down or tired",
#     "Feeling run-down or tired",
#     "Fever",
#     "Frequently waking",
#     "Headache",
#     "Loss of appetite",
#     "Loss of appetite and unintentional weight loss",
#     "Low-grade fever",
#     "Morning headaches",
#     "Nasal congestion",
#     "Nausea",
#     "Night sweats",
#     "Pauses in breathing",
#     "Persistent dry coug",
#     "Persistent dry cough",
#     "Rapid breathing",
#     "Rapid heartbeat",
#     "Runny nose",
#     "Shortness of breath",
#     "Shortness of breath that gets worse during flare-ups",
#     "Snoring",
#     "Sore throat",
#     "Unusual moodiness",
#     "Weight loss from loss of appetite",
#     "Wheezing",
#     "Wider and rounder than normal fingertips and toes",
#     "allergy",
#     "breath",
#     "chest pain",
#     "chronic cough",
#     "cold",
#     "cough",
#     "cough with blood",
#     "coughing",
#     "diarrhea",
#     "distressing",
#     "dizziness",
#     "dry cough",
#     "edema",
#     "fainting",
#     "faster heart beating",
#     "fatigue",
#     "fever",
#     "greenish cough",
#     "heart palpitations",
#     "high fever",
#     "irritability",
#     "joint pain",
#     "loss of appetite",
#     "low energy",
#     "lower back pain",
#     "mucus",
#     "muscle aches",
#     "nan",
#     "nausea",
#     "pain",
#     "runny nose",
#     "shaking",
#     "shallow breathing",
#     "sharp chest pain",
#     "short of breath",
#     "short, shallow and rapid breathing",
#     "shortness of breath",
#     "stuffy nose",
#     "sweating",
#     "tight feeling in the chest",
#     "vomiting",
#     "weight loss",
#     "wheezing",
#     "wheezing cough",
#     "whistling sound while breathing",
#     "whistling sound while you breathe",
#     "yellow cough"
#   ],
#   "diseases": {
#     "Asthma": {
#       "weights": {
#         "shortness of breath": 0.2956204379562044,
#         "coughing": 0.11405109489051095,
#         "wheezing": 0.11405109489051095,
#         "fever": 0.11405109489051095,
#         "cold": 0.11405109489051095,
#         "tight feeling in the chest": 0.11313868613138686,
#         "allergy": 0.09124087591240876,
#         "nan": 0.043795620437956206
#       },
#       "age_profile": {
#         "min": 2.0,
#         "max": 87.0,
#         "mean": 32.94618395303327,
#         "std": 25.660253683780706
#       },
#       "treatment": "Mepolizumab"
#     },
#     "nan": {
#       "weights": {
#         "nan": 0.5647058823529412,
#         "cold": 0.07352941176470588,
#         "fever": 0.07352941176470588,
#         "stuffy nose": 0.07352941176470588,
#         "loss of appetite": 0.07352941176470588,
#         "Chest tightness or chest pain": 0.07058823529411765,
#         "tight feeling in the chest": 0.07058823529411765
#       },
#       "age_profile": {
#         "min": 11.0,
#         "max": 85.0,
#         "mean": 34.54794520547945,
#         "std": 27.856673472108888
#       },
#       "treatment": "nan"
#     },
#     "Bronchiectasis": {
#       "weights": {
#         "Fatigue, feeling run-down or tired": 0.20512820512820512,
#         "Coughing up blood": 0.16666666666666666,
#         "Shortness of breath that gets worse during flare-ups": 0.14102564102564102,
#         "whistling sound while you breathe": 0.11538461538461539,
#         "Coughing up yellow or green mucus daily": 0.10256410256410256,
#         "Chest pain": 0.10256410256410256,
#         "Wheezing": 0.08974358974358974,
#         "fever": 0.0641025641025641,
#         "coughing": 0.01282051282051282
#       },
#       "age_profile": {
#         "min": 2.0,
#         "max": 80.0,
#         "mean": 32.85526315789474,
#         "std": 28.396548727915565
#       },
#       "treatment": "hypertonic saline"
#     },
#     "bronchiolitis": {
#       "weights": {
#         "cough": 0.3113207547169811,
#         "loss of appetite": 0.3018867924528302,
#         "stuffy nose": 0.24528301886792453,
#         "runny nose": 0.09433962264150944,
#         "fever": 0.02830188679245283,
#         "cold": 0.018867924528301886
#       },
#       "age_profile": {
#         "min": 1.0,
#         "max": 89.0,
#         "mean": 30.442307692307693,
#         "std": 27.565315390948825
#       },
#       "treatment": "saline nose drops"
#     },
#     "bronchitis": {
#       "weights": {
#         "Wheezing": 0.16893401015228426,
#         "yellow cough": 0.15878172588832487,
#         "Low-grade fever": 0.13908629441624365,
#         "Feeling run-down or tired": 0.1267005076142132,
#         "whistling sound while breathing": 0.10923857868020305,
#         "Runny nose": 0.10862944162436548,
#         "stuffy nose": 0.09928934010152285,
#         "Chest congestion": 0.08934010152284264
#       },
#       "age_profile": {
#         "min": 1.0,
#         "max": 87.0,
#         "mean": 28.71959390862944,
#         "std": 25.723494395771517
#       },
#       "treatment": "antibiotics"
#     },
#     "Chronic Bronchitis": {
#       "weights": {
#         "chest pain": 0.2619047619047619,
#         "mucus": 0.23809523809523808,
#         "shortness of breath": 0.23809523809523808,
#         "wheezing": 0.19047619047619047,
#         "Wheezing": 0.07142857142857142
#       },
#       "age_profile": {
#         "min": 1.0,
#         "max": 87.0,
#         "mean": 31.642857142857142,
#         "std": 25.63262941818017
#       },
#       "treatment": "steroids to reduce inflammation"
#     },
#     "Chronic cough": {
#       "weights": {
#         "shortness of breath": 0.5263157894736842,
#         "cold": 0.42105263157894735,
#         "nan": 0.05263157894736842
#       },
#       "age_profile": {
#         "min": 5.0,
#         "max": 78.0,
#         "mean": 26.473684210526315,
#         "std": 25.425023077400276
#       },
#       "treatment": "nan"
#     },
#     "chronic obstructive pulmonary disease": {
#       "weights": {
#         "Fatigue": 0.25925925925925924,
#         "chronic cough": 0.2222222222222222,
#         "mucus": 0.1728395061728395,
#         "shortness of breath": 0.14814814814814814,
#         "Wheezing": 0.09876543209876543,
#         "cold": 0.09876543209876543
#       },
#       "age_profile": {
#         "min": 4.0,
#         "max": 90.0,
#         "mean": 43.666666666666664,
#         "std": 27.330975989172252
#       },
#       "treatment": "Pulmonary rehabilitation"
#     },
#     "Mesothelioma": {
#       "weights": {
#         "lower back pain": 0.34328358208955223,
#         "dry cough": 0.23880597014925373,
#         "chest pain": 0.208955223880597,
#         "shortness of breath": 0.19402985074626866,
#         "nan": 0.014925373134328358
#       },
#       "age_profile": {
#         "min": 6.0,
#         "max": 90.0,
#         "mean": 48.24242424242424,
#         "std": 26.81618197033863
#       },
#       "treatment": "Chemotherapy"
#     },
#     "Pneumonia": {
#       "weights": {
#         "Nausea": 0.109375,
#         "chest pain": 0.109375,
#         "Rapid breathing": 0.0546875,
#         "greenish cough": 0.0546875,
#         "yellow cough": 0.0546875,
#         "sweating": 0.0546875,
#         "shaking": 0.0546875,
#         "cough with blood": 0.0546875,
#         "Fever": 0.0546875,
#         "Loss of appetite": 0.0546875,
#         "shortness of breath": 0.0546875,
#         "low energy": 0.0546875,
#         "shallow breathing": 0.0546875,
#         "vomiting": 0.0546875,
#         "fatigue": 0.0546875,
#         "cold": 0.0546875,
#         "nan": 0.015625
#       },
#       "age_profile": {
#         "min": 1.0,
#         "max": 90.0,
#         "mean": 35.390625,
#         "std": 27.29182374212264
#       },
#       "treatment": "Antibiotic"
#     },
#     "Pneumothorax": {
#       "weights": {
#         "sharp chest pain": 0.08333333333333333,
#         "shortness of breath": 0.08333333333333333,
#         "Bluish skin": 0.08333333333333333,
#         "Fatigue": 0.08333333333333333,
#         "Rapid breathing": 0.08333333333333333,
#         "Rapid heartbeat": 0.08333333333333333,
#         "dry cough": 0.08333333333333333,
#         "nan": 0.08333333333333333,
#         "fever": 0.08333333333333333,
#         "cold": 0.08333333333333333,
#         "low energy": 0.08333333333333333,
#         "fatigue": 0.08333333333333333
#       },
#       "age_profile": {
#         "min": 1.0,
#         "max": 90.0,
#         "mean": 44.86666666666667,
#         "std": 29.314625587900746
#       },
#       "treatment": "isotonic sodium chloride solution"
#     },
#     "Influenza": {
#       "weights": {
#         "high fever": 0.07692307692307693,
#         "Headache": 0.07692307692307693,
#         "muscle aches": 0.07692307692307693,
#         "joint pain": 0.07692307692307693,
#         "cough": 0.07692307692307693,
#         "Chills": 0.07692307692307693,
#         "Sore throat": 0.07692307692307693,
#         "Nasal congestion": 0.07692307692307693,
#         "runny nose": 0.07692307692307693,
#         "Fatigue": 0.07692307692307693,
#         "nausea": 0.07692307692307693,
#         "vomiting": 0.07692307692307693,
#         "diarrhea": 0.07692307692307693
#       },
#       "age_profile": {
#         "min": 5.0,
#         "max": 89.0,
#         "mean": 30.333333333333332,
#         "std": 22.890812797476826
#       },
#       "treatment": "Oseltamivir"
#     },
#     "Pulmonary hypertension": {
#       "weights": {
#         "breath": 0.14285714285714285,
#         "fatigue": 0.14285714285714285,
#         "chest pain": 0.14285714285714285,
#         "dizziness": 0.14285714285714285,
#         "fainting": 0.14285714285714285,
#         "heart palpitations": 0.14285714285714285,
#         "edema": 0.14285714285714285
#       },
#       "age_profile": {
#         "min": 1.0,
#         "max": 76.0,
#         "mean": 29.02857142857143,
#         "std": 23.94214075586086
#       },
#       "treatment": "Diuretics"
#     },
#     "sleep apnea": {
#       "weights": {
#         "Snoring": 0.1111111111111111,
#         "Daytime sleepiness": 0.1111111111111111,
#         "Pauses in breathing": 0.1111111111111111,
#         "Difficulties with memory and concentration": 0.1111111111111111,
#         "Unusual moodiness": 0.1111111111111111,
#         "irritability": 0.1111111111111111,
#         "Frequently waking": 0.1111111111111111,
#         "Morning headaches": 0.1111111111111111,
#         "Dry mouth": 0.1111111111111111
#       },
#       "age_profile": {
#         "min": 14.0,
#         "max": 90.0,
#         "mean": 50.05555555555556,
#         "std": 28.773244084140583
#       },
#       "treatment": "Adaptive servo-ventilation"
#     },
#     "Respiratory syncytial virus": {
#       "weights": {
#         "short, shallow and rapid breathing": 0.4666666666666667,
#         "wheezing cough": 0.26666666666666666,
#         "cold": 0.26666666666666666
#       },
#       "age_profile": {
#         "min": 20.0,
#         "max": 90.0,
#         "mean": 62.46666666666667,
#         "std": 20.974426444438407
#       },
#       "treatment": "Intravenous fluids"
#     },
#     "Tuberculosis": {
#       "weights": {
#         "A cough that lasts more than three weeks": 0.2,
#         "Loss of appetite and unintentional weight loss": 0.2,
#         "Fever": 0.2,
#         "Chills": 0.2,
#         "Night sweats": 0.2
#       },
#       "age_profile": {
#         "min": 6.0,
#         "max": 89.0,
#         "mean": 38.77142857142857,
#         "std": 22.076700836316487
#       },
#       "treatment": "ethambutol"
#     },
#     "Acute Respiratory Distress Syndrome": {
#       "weights": {
#         "short of breath": 0.20689655172413793,
#         "distressing": 0.20689655172413793,
#         "faster heart beating": 0.20689655172413793,
#         "pain": 0.20689655172413793,
#         "cough": 0.1724137931034483
#       },
#       "age_profile": {
#         "min": 3.0,
#         "max": 90.0,
#         "mean": 47.3448275862069,
#         "std": 25.38898082453016
#       },
#       "treatment": "consult doctor"
#     },
#     "Asbestosis": {
#       "weights": {
#         "A dry, crackling sound in the lungs while breathing in": 0.2857142857142857,
#         "Shortness of breath": 0.23809523809523808,
#         "Weight loss from loss of appetite": 0.14285714285714285,
#         "Wider and rounder than normal fingertips and toes": 0.14285714285714285,
#         "Persistent dry coug": 0.09523809523809523,
#         "Persistent dry cough": 0.047619047619047616,
#         "nan": 0.047619047619047616
#       },
#       "age_profile": {
#         "min": 1.0,
#         "max": 89.0,
#         "mean": 33.72222222222222,
#         "std": 31.13769534105501
#       },
#       "treatment": "stay away from cold places"
#     },
#     "Aspergillosis": {
#       "weights": {
#         "wheezing": 0.2857142857142857,
#         "shortness of breath": 0.2857142857142857,
#         "weight loss": 0.23809523809523808,
#         "fatigue": 0.19047619047619047
#       },
#       "age_profile": {
#         "min": 3.0,
#         "max": 98.0,
#         "mean": 45.04761904761905,
#         "std": 32.24036395387688
#       },
#       "treatment": "nan"
#     }
#   }
# }
